# %%
# !nvidia-smi
# Out:
# Sun May 18 05:28:36 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 62.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 83.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 841.5 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 111.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="<Enter Your API Key Ere>")
project = rf.workspace("testworkspace-qz0ne").project("fire_detection-nhru2")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 124.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to fire_detection-2 in yolov11:: 100%|██████████| 36938/36938 [00:06<00:00, 5500.63it/s]

# %%
# !yolo task=detect mode=train model=yolo11s.pt data={dataset.location}/data.yaml epochs=20 imgsz=640 degrees=10.0 translate=0.1 scale=0.5 shear=2.0 perspective=0.0 mixup=0.2 plots=True
# Out:
# ...
# 100% 18.4M/18.4M [00:00<00:00, 479MB/s]
# Ultralytics 8.3.138 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# prompt: create the runs folder to zip and download it

import os
# Define the path to the runs directory
runs_dir = '/content/runs'
dataset = '/content/fire_detection-2'
# Create the directory if it doesn't exist
os.makedirs(runs_dir, exist_ok=True)
os.makedirs(dataset,exist_ok=True)
# Zip the runs directory
# !zip -r /content/runs.zip {runs_dir}
# !zip -r /content/data.zip {dataset}
# Download the zipped file
from google.colab import files
files.download('/content/runs.zip')
files.download('/content/data.zip')
#
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/fire_detection-2/train/images/large_-1505-_jpg.rf.19c3521ac0ab6c4012520bbfd3663265.jpg (deflated 0%)
#   adding: content/fire_detection-2/train/images/middle_-2651-_jpg.rf.87de17f82ac52c0ffe461afc18d1b45e.jpg (deflated 0%)
#   adding: content/fire_detection-2/train/images/large_-580-_jpg.rf.be837db89efd9dbac1bc3aedfc18d105.jpg (deflated 6%)
#   adding: content/fire_detection-2/train/images/large_-11-_jpg.rf.96e0ab3976f507585e1bd7199096ae99.jpg (deflated 0%)
#   adding: content/fire_detection-2/train/images/large_-201-_jpg.rf.6d73f8e27e4ddd7d4aa45fbdf7bcfa28.jpg (deflated 0%)
#   adding: content/fire_detection-2/train/images/middle_-760-_jpg.rf.6e2b255e9fad066f10bb22cb91c31910.jpg (deflated 0%)
#   adding: content/fire_detection-2/train/images/large_-786-_jpg.rf.14619038ff7c817f9cb05b75f0c12c8b.jpg (deflated 0%)
# ...
