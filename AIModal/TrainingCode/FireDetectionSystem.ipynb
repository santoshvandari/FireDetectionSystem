# %%
# !nvidia-smi
# Out:
# Mon Jun 16 10:14:38 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 25.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 26.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 61.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="WPZf7raYBJp84hjgHLU6")
project = rf.workspace("testworkspace-qz0ne").project("fire_detection-nhru2")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 24.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 126.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to fire_detection-2 in yolov8:: 100%|██████████| 36938/36938 [00:06<00:00, 5964.55it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# ...

# %%
# !yolo task=detect mode=train model=yolo11m.pt data={dataset.location}/data.yaml epochs=20 imgsz=640 degrees=10.0 translate=0.1 scale=0.5 shear=2.0 perspective=0.0 mixup=0.2 plots=True
# Out:
# ...
# 100% 38.8M/38.8M [00:00<00:00, 260MB/s]
# Ultralytics 8.3.155 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# prompt: create the runs folder to zip and download it

import os
# Define the path to the runs directory
runs_dir = '/content/runs'
dataset = '/content/fire_detection-2'
# Create the directory if it doesn't exist
os.makedirs(runs_dir, exist_ok=True)
os.makedirs(dataset,exist_ok=True)
# Zip the runs directory
# !zip -r /content/runs.zip {runs_dir}
# !zip -r /content/data.zip {dataset}
# Download the zipped file
from google.colab import files
files.download('/content/runs.zip')
files.download('/content/data.zip')
#
# Out:
# Streaming output truncated to the last 5000 lines.
# updating: content/fire_detection-2/train/images/middle_-3055-_jpg.rf.5c282f098555f4d798f1252b01b019e0.jpg (deflated 1%)
# updating: content/fire_detection-2/train/images/large_-2867-_jpg.rf.13f7e855cbb990e03fac39ccdf5cb9b9.jpg (deflated 1%)
# updating: content/fire_detection-2/train/images/large_-373-_jpg.rf.a379f430fc052ac7bbba88a42629dc7c.jpg (deflated 1%)
# updating: content/fire_detection-2/train/images/large_-1801-_jpg.rf.199bc0dd659dca212859212a2c8d9da4.jpg (deflated 0%)
# updating: content/fire_detection-2/train/images/large_-42-_jpg.rf.811005106b904f99624f51b34c93a502.jpg (deflated 1%)
# updating: content/fire_detection-2/train/images/middle_-1838-_jpg.rf.6700b8672764acd58dfc56b3ba447128.jpg (deflated 1%)
# updating: content/fire_detection-2/train/images/middle_-13-_jpg.rf.2cac5c80e208ad0662984111c116338c.jpg (deflated 0%)
# ...
